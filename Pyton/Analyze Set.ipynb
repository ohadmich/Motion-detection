# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as sp
from IPython.display import Image
import time
import pickle

# %% [markdown]
# Define functions:

# %%
def minfunc(beta):
    D_k = (Pr_k*N_k - beta*Pn_k*R_k)/np.sqrt(sigma_n**2*np.square(np.abs(Pr_k)) + beta**2*sigma_r**2*np.square(np.abs(Pn_k))+1e-50)
    D_q = np.abs(np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(D_k))))
    return np.sqrt(np.mean(np.square(D_q)))

# %%
def minfunc0(beta):
    D_k0 = (Pr_k*N_k0 - beta*Pn_k*R_k)/np.sqrt(sigma_n**2*np.square(np.abs(Pr_k)) + beta**2*sigma_r**2*np.square(np.abs(Pn_k))+1e-50)
    D_q0 = np.abs(np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(D_k0))))
    return np.sqrt(np.mean(np.square(D_q0)))

# %% [markdown]
# Analyze data:

# %%
Dirname = 'Simulated Data\Movment of +0.4 in y set2'
Set_size = 100 # Number of images in a set
ZeroMove_max = np.zeros(Set_size, dtype=float) # allocate memoty for maximal zero movement detection value
FiniteMove_max = np.zeros(Set_size, dtype=float) # allocate memoty for maximal finite movement detection value

for ind in range(1,Set_size+1):    
    with open(Dirname + '\\' + str(ind) + '.pickle') as f:
        N_q,R_q,Pn_q,Pr_q,q,sigma_n,N_q0,N = pickle.load(f)
    
    # Move to k-space
    sigma_r = sigma_n # Noise Stdv is the same for both images
    N_k = np.fft.fftshift(np.fft.fft2(N_q))
    N_k0 = np.fft.fftshift(np.fft.fft2(N_q0))
    R_k = np.fft.fftshift(np.fft.fft2(R_q))
    Pn_k = np.fft.fftshift(np.fft.fft2(Pn_q))
    Pr_k = np.fft.fftshift(np.fft.fft2(Pr_q))
    
    # *******Compute S for zero movement********
    
    betaOpt0 = sp.fmin(minfunc0, x0 = 2) # Find beta for zero movement
    
    D_k0 = lambda beta: (Pr_k*N_k0 - beta*Pn_k*R_k)/np.sqrt(sigma_n**2*np.square(np.abs(Pr_k)) 
                                                      + beta**2*sigma_r**2*np.square(np.abs(Pn_k))+1e-50)

    D_q0 = np.real(np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(D_k0(betaOpt0)))))
    
    Fn = 1.2 # New flux
    FD = lambda beta: Fn/np.sqrt(sigma_n**2 + beta**2*sigma_r**2) # Difference image PSF normalization
    PD_k = lambda beta: Fn*Pr_k*Pn_k/(FD(beta)*np.sqrt(sigma_n**2*np.square(np.abs(Pr_k)) + beta**2*sigma_r**2*np.square(np.abs(Pn_k))+1e-50)) # Difference image PSF 

    # Create M matrix
    k = np.linspace(-np.pi,np.pi-2*np.pi/N,N)
    kx, ky = np.meshgrid(k,k)
    dq = np.arange(-30,30,0.4)

    i = 0
    S0 = np.zeros((len(dq),N,N))
    for l in dq:

        M = np.exp(-1j*(kx*0 + ky*l))-1
        S_q = lambda beta: np.real(np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(FD(beta)*D_k0(beta)*PD_k(beta).conj()*M.conj()))))
        S0[i] = S_q(betaOpt0)
        i = i+1
    
    S0max = np.amax(np.amax(S0,axis=1), axis=1) # Vector of maximal pixel value for each dq
    std0 = np.std(S0[np.argmax(S0max),:,:]) # Stdev of the S0 image with maximal pixel value 
    S0max = S0max/std0 # normlization
    ZeroMove_max[ind-1] = np.max(S0max)
    # *******Compute S for finite movement********
    
    betaOpt = sp.fmin(minfunc, x0 = 2) # Find beta for finite movement
    
    D_k = lambda beta: (Pr_k*N_k - beta*Pn_k*R_k)/np.sqrt(sigma_n**2*np.square(np.abs(Pr_k)) 
                                                      + beta**2*sigma_r**2*np.square(np.abs(Pn_k))+1e-50)

    D_q = np.real(np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(D_k(betaOpt)))))
    
    i = 0
    S = np.zeros((len(dq),N,N))
    for l in dq:

        M = np.exp(-1j*(kx*0 + ky*l))-1

        S_q = lambda beta: np.real(np.fft.ifftshift(np.fft.ifft2(np.fft.ifftshift(FD(beta)*D_k(beta)*PD_k(beta).conj()*M.conj()))))
        S[i] = S_q(betaOpt)
        i = i+1
    Smax = np.amax(np.amax(S,axis=1), axis=1)/std0
    FiniteMove_max[ind-1] = np.max(Smax)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.999367
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998395
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000474
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000992
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000776
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001047
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999200
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999694
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.996531
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.997791
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000812
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000276
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999677
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000732
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001390
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999747
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998498
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.997476
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000430
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001082
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999807
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999333
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999378
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001698
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998169
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000023
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000137
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998992
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.997947
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.997969
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999185
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999805
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001436
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000920
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000595
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000162
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000984
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999317
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000393
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999398
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000102
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.001862
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999891
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000717
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998085
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998091
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998540
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998643
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000444
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001149
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999114
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000637
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999794
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999445
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998753
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999671
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999490
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001710
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999443
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999294
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999677
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998908
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999457
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000397
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000350
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000199
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000798
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999740
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000750
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999930
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998819
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999933
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001491
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001177
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.997924
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999036
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000664
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998864
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.997942
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998177
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998981
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000570
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.001040
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999982
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998379
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000093
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999784
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.999493
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002010
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001240
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998748
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999820
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002461
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999829
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999585
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000219
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.998065
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999246
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001037
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000918
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000887
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000393
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.999290
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000433
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998794
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999118
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000091
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998978
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999105
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998757
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001981
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999150
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.999273
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000904
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001631
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000240
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002332
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002088
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000316
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001019
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001006
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002872
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999448
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000067
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.002829
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002671
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998426
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.997736
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.999929
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998089
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.001626
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000938
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000113
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999978
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000413
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999197
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000180
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999094
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999961
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000417
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000045
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999821
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.001098
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000916
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001089
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000226
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.002824
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.003197
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000004
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999635
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001620
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999609
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.999897
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000917
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998938
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999185
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000347
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000530
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999602
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998701
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.999720
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999089
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999828
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000847
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001468
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001383
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000542
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999459
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000541
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000581
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001548
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000885
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001900
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001364
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000606
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999227
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.998863
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998283
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000581
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000410
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000173
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998767
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.998822
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000553
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001024
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.001045
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001333
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000388
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.000765
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000252
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001563
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 1.002949
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000327
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000137
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000867
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001091
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.003071
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.000707
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 1.001096
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.999699
#          Iterations: 16
#          Function evaluations: 32

# %% [markdown]
# Save results:

# %%
with open(Dirname + '\\' + 'results1.pickle', 'w') as f:
    pickle.dump([ZeroMove_max,FiniteMove_max], f)

# %% [markdown]
# Load results:

# %%
with open('Simulated Data\Movment of +0.4 in y set2\\results1.pickle') as f:
    ZeroMove_max,FiniteMove_max = pickle.load(f)

# %% [markdown]
# Successful detections:

# %%
eta = 5 # Define detection threshold for Dq=0.4
# eta = 7 # Define detection threshold for Dq=0.8

plt.figure()
plt.plot(ZeroMove_max,'o')
plt.plot(FiniteMove_max,'o')
plt.plot(eta*(np.ones(len(FiniteMove_max))),'r')

print 'Number of successful detections = %r' %np.sum(FiniteMove_max>eta)
print 'Successful detections fraction = %r' %(np.sum(FiniteMove_max>eta)/float(len(FiniteMove_max)))

print '--------------------------------------'

print 'Number of false positives = %r' %np.sum(ZeroMove_max>eta)
print 'false positive fraction = %r' %(np.sum(ZeroMove_max>eta)/float(len(ZeroMove_max)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Number of successful detections = 52
# Successful detections fraction = 0.52000000000000002
# --------------------------------------
# Number of false positives = 5
# false positive fraction = 0.050000000000000003
